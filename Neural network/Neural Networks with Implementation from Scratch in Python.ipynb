# %% [markdown]
# # Neural Networks with Implementation from Scratch in Python

# %% [markdown]
# ### *What is a Neural Network*

# %% [markdown]
# A neural network is a computational model inspired by the structure and function of the human brain's interconnected network of neurons. It's a type of machine learning algorithm that is capable of learning from data. Neural networks consist of layers of interconnected nodes, or "neurons," organized into an input layer, one or more hidden layers, and an output layer.
#
# Each neuron in a neural network receives input signals, processes them via a mathematical operation (typically a weighted sum), and then applies an activation function to produce an output. The weights and biases associated with connections between neurons are adjusted during the training process, where the network learns to map input data to desired outputs.
#
# Neural networks are widely used in various fields, including image and speech recognition, natural language processing, medical diagnosis, finance, and more. They have shown remarkable performance in tasks such as classification, regression, pattern recognition, and even creative tasks like generating art or music. Deep learning, a subset of neural networks, involves using neural networks with many hidden layers, enabling them to learn complex patterns and representations from data.

# %% [markdown]
# ### Learning In Neural Networks

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

def relu(z):
    a = np.maximum(0,z)
    return a

def initialize_params(layer_sizes):
    params = {}
    for i in range(1, len(layer_sizes)):
        params['W' + str(i)] = np.random.randn(layer_sizes[i], layer_sizes[i-1])*0.01
        params['B' + str(i)] = np.random.randn(layer_sizes[i],1)*0.01
    return params

def forward_propagation(X_train, params):
    layers = len(params)//2
    values = {}
    for i in range(1, layers+1):
        if i==1:
            values['Z' + str(i)] = np.dot(params['W' + str(i)], X_train) + params['B' + str(i)]
            values['A' + str(i)] = relu(values['Z' + str(i)])
        else:
            values['Z' + str(i)] = np.dot(params['W' + str(i)], values['A' + str(i-1)]) + params['B' + str(i)]
            if i==layers:
                values['A' + str(i)] = values['Z' + str(i)]
            else:
                values['A' + str(i)] = relu(values['Z' + str(i)])
    return values

def compute_cost(values, Y_train):
    layers = len(values)//2
    Y_pred = values['A' + str(layers)]
    cost = 1/(2*len(Y_train)) * np.sum(np.square(Y_pred - Y_train))
    return cost

def backward_propagation(params, values, X_train, Y_train):
    layers = len(params)//2
    m = len(Y_train)
    grads = {}
    for i in range(layers,0,-1):
        if i==layers:
            dA = 1/m * (values['A' + str(i)] - Y_train)
            dZ = dA
        else:
            dA = np.dot(params['W' + str(i+1)].T, dZ)
            dZ = np.multiply(dA, np.where(values['A' + str(i)]>=0, 1, 0))
        if i==1:
            grads['W' + str(i)] = 1/m * np.dot(dZ, X_train.T)
            grads['B' + str(i)] = 1/m * np.sum(dZ, axis=1, keepdims=True)
        else:
            grads['W' + str(i)] = 1/m * np.dot(dZ,values['A' + str(i-1)].T)
            grads['B' + str(i)] = 1/m * np.sum(dZ, axis=1, keepdims=True)
    return grads

def update_params(params, grads, learning_rate):
    layers = len(params)//2
    params_updated = {}
    for i in range(1,layers+1):
        params_updated['W' + str(i)] = params['W' + str(i)] - learning_rate * grads['W' + str(i)]
        params_updated['B' + str(i)] = params['B' + str(i)] - learning_rate * grads['B' + str(i)]
    return params_updated

def model(X_train, Y_train, layer_sizes, num_iters, learning_rate):
    params = initialize_params(layer_sizes)
    for i in range(num_iters):
        values = forward_propagation(X_train.T, params)
        cost = compute_cost(values, Y_train.T)
        grads = backward_propagation(params, values,X_train.T, Y_train.T)
        params = update_params(params, grads, learning_rate)
        print('Cost at iteration ' + str(i+1) + ' = ' + str(cost) + '\n')
    return params

def compute_accuracy(X_train, X_test, Y_train, Y_test, params):
    values_train = forward_propagation(X_train.T, params)
    values_test = forward_propagation(X_test.T, params)
    train_acc = np.sqrt(mean_squared_error(Y_train, values_train['A' + str(len(layer_sizes)-1)].T))
    test_acc = np.sqrt(mean_squared_error(Y_test, values_test['A' + str(len(layer_sizes)-1)].T))
    return train_acc, test_acc

def predict(X, params):
    values = forward_propagation(X.T, params)
    predictions = values['A' + str(len(values)//2)].T
    return predictions

data = load_boston()                                                              #load dataset
X,Y = data["data"], data["target"]                                                #separate data into input and output features
X_train,X_test,Y_train,Y_test = train_test_split(X, Y, test_size = 0.2)           #split data into train and test sets in 80-20 ratio
layer_sizes = [13, 5, 5, 1]                                                       #set layer sizes, do not change the size of the first and last layer 
num_iters = 1000                                                                  #set number of iterations over the training set(also known as epochs in batch gradient descent context)
learning_rate = 0.03                                                              #set learning rate for gradient descent
params = model(X_train, Y_train, layer_sizes, num_iters, learning_rate)           #train the model
train_acc, test_acc = compute_accuracy(X_train, X_test, Y_train, Y_test, params)  #get training and test accuracy
print('Root Mean Squared Error on Training Data = ' + str(train_acc))
print('Root Mean Squared Error on Test Data = ' + str(test_acc))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#         target = raw_df.values[1::2, 2]
#
#     Alternative datasets include the California housing dataset (i.e.
#     :func:`~sklearn.datasets.fetch_california_housing`) and the Ames housing
#     dataset. You can load the datasets as follows::
#
#         from sklearn.datasets import fetch_california_housing
#         housing = fetch_california_housing()
#
#     for the California housing dataset and::
#
#         from sklearn.datasets import fetch_openml
#         housing = fetch_openml(name="house_prices", as_frame=True)
#
#     for the Ames housing dataset.
#
#   warnings.warn(msg, category=FutureWarning)
# Cost at iteration 1 = 289.6943019497903
#
# Cost at iteration 2 = 289.65368327539824
#
# Cost at iteration 3 = 289.61306566583966
#
# Cost at iteration 4 = 289.5724351052462
#
# Cost at iteration 5 = 289.53177957477044
#
# Cost at iteration 6 = 289.49108897497274
#
# Cost at iteration 7 = 289.45035162168773
#
# Cost at iteration 8 = 289.4095556988802
#
# Cost at iteration 9 = 289.36868839343884
#
# Cost at iteration 10 = 289.32773418794716
#
# Cost at iteration 11 = 289.28670149328474
#
# Cost at iteration 12 = 289.24561921289495
#
# Cost at iteration 13 = 289.2045785936948
#
# Cost at iteration 14 = 289.16373205384815
#
# Cost at iteration 15 = 289.1231435327659
#
# Cost at iteration 16 = 289.0827481540541
#
# Cost at iteration 17 = 289.0422668532986
#
# Cost at iteration 18 = 289.00165560243966
#
# Cost at iteration 19 = 288.9608480954798
#
# Cost at iteration 20 = 288.91979456437247
#
# Cost at iteration 21 = 288.87846163453753
#
# Cost at iteration 22 = 288.83681725684124
#
# Cost at iteration 23 = 288.7948271402489
#
# Cost at iteration 24 = 288.7524568169102
#
# Cost at iteration 25 = 288.7096742031097
#
# Cost at iteration 26 = 288.6664480787472
#
# Cost at iteration 27 = 288.62273131162
#
# Cost at iteration 28 = 288.57846662622023
#
# Cost at iteration 29 = 288.5335902030444
#
# Cost at iteration 30 = 288.4880340753456
#
# Cost at iteration 31 = 288.44172029387715
#
# Cost at iteration 32 = 288.3945643302214
#
# Cost at iteration 33 = 288.34647230209987
#
# Cost at iteration 34 = 288.2973347571159
#
# Cost at iteration 35 = 288.24702716223106
#
# Cost at iteration 36 = 288.19540853900764
#
# Cost at iteration 37 = 288.14231735955434
#
# Cost at iteration 38 = 288.08756625654377
#
# Cost at iteration 39 = 288.0309415849252
#
# Cost at iteration 40 = 287.9721958393164
#
# Cost at iteration 41 = 287.9110429499856
#
# Cost at iteration 42 = 287.84714732915796
#
# Cost at iteration 43 = 287.7801171871089
#
# Cost at iteration 44 = 287.70949532968314
#
# Cost at iteration 45 = 287.6347400023142
#
# Cost at iteration 46 = 287.5552133526746
#
# Cost at iteration 47 = 287.47015410856307
#
# Cost at iteration 48 = 287.3786508007556
#
# Cost at iteration 49 = 287.2796112802957
#
# Cost at iteration 50 = 287.1717172885193
#
# Cost at iteration 51 = 287.0533685770585
#
# Cost at iteration 52 = 286.9226096406201
#
# Cost at iteration 53 = 286.77703519846176
#
# Cost at iteration 54 = 286.61366743016123
#
# Cost at iteration 55 = 286.4287916017674
#
# Cost at iteration 56 = 286.2177377295954
#
# Cost at iteration 57 = 285.97458538040536
#
# Cost at iteration 58 = 285.6917614564181
#
# Cost at iteration 59 = 285.3594851307367
#
# Cost at iteration 60 = 284.96499462826523
#
# Cost at iteration 61 = 284.49145373480553
#
# Cost at iteration 62 = 283.91638594489757
#
# Cost at iteration 63 = 283.2094019564634
#
# Cost at iteration 64 = 282.32885166347734
#
# Cost at iteration 65 = 281.21681738987513
#
# Cost at iteration 66 = 279.7915130184194
#
# Cost at iteration 67 = 277.9355735630847
#
# Cost at iteration 68 = 275.4777748845747
#
# Cost at iteration 69 = 272.16423344809783
#
# Cost at iteration 70 = 267.6129253094496
#
# Cost at iteration 71 = 261.2428689086406
#
# Cost at iteration 72 = 252.16918230667267
#
# Cost at iteration 73 = 239.0687036912333
#
# Cost at iteration 74 = 220.08638774819812
#
# Cost at iteration 75 = 193.07447491987733
#
# Cost at iteration 76 = 156.98922676102416
#
# Cost at iteration 77 = 115.61996181664938
#
# Cost at iteration 78 = 81.14430122994766
#
# Cost at iteration 79 = 64.98709553932052
#
# Cost at iteration 80 = 61.34840369930815
#
# Cost at iteration 81 = 60.192682677689376
#
# Cost at iteration 82 = 59.19635439524205
#
# Cost at iteration 83 = 58.235290983293034
#
# Cost at iteration 84 = 57.30559805652126
#
# Cost at iteration 85 = 56.40588108239643
#
# Cost at iteration 86 = 55.53497600298377
#
# Cost at iteration 87 = 54.691892596238716
#
# Cost at iteration 88 = 53.87579330959024
#
# Cost at iteration 89 = 53.08597501719864
#
# Cost at iteration 90 = 52.32185250247187
#
# Cost at iteration 91 = 51.58294326913236
#
# Cost at iteration 92 = 50.86885339587345
#
# Cost at iteration 93 = 50.17926421317386
#
# Cost at iteration 94 = 49.51391963369911
#
# Cost at iteration 95 = 48.87261401468567
#
# Cost at iteration 96 = 48.2551804732198
#
# Cost at iteration 97 = 47.66147961409717
#
# Cost at iteration 98 = 47.09138866525528
#
# Cost at iteration 99 = 46.54479104753998
#
# Cost at iteration 100 = 46.02156643345316
#
# Cost at iteration 101 = 45.521581372985665
#
# Cost at iteration 102 = 45.04468058299325
#
# Cost at iteration 103 = 44.590679009121835
#
# Cost at iteration 104 = 44.1593547753845
#
# Cost at iteration 105 = 43.75044313565086
#
# Cost at iteration 106 = 43.36363153328728
#
# Cost at iteration 107 = 42.99855586007245
#
# Cost at iteration 108 = 42.65479798376675
#
# Cost at iteration 109 = 42.33188458620642
#
# Cost at iteration 110 = 42.029287321777026
#
# Cost at iteration 111 = 41.746424271191145
#
# Cost at iteration 112 = 41.48266262949181
#
# Cost at iteration 113 = 41.23732253209598
#
# Cost at iteration 114 = 41.009681890439616
#
# Cost at iteration 115 = 40.798982081186146
#
# Cost at iteration 116 = 40.6044343115214
#
# Cost at iteration 117 = 40.42522646887708
#
# Cost at iteration 118 = 40.2605302571189
#
# Cost at iteration 119 = 40.10950842290078
#
# Cost at iteration 120 = 39.971321885115934
#
# Cost at iteration 121 = 39.84513659631647
#
# Cost at iteration 122 = 39.730129986409736
#
# Cost at iteration 123 = 39.62549686441874
#
# Cost at iteration 124 = 39.53045468204467
#
# Cost at iteration 125 = 39.444248091623656
#
# Cost at iteration 126 = 39.36615275937925
#
# Cost at iteration 127 = 39.29547842138556
#
# Cost at iteration 128 = 39.23157119338331
#
# Cost at iteration 129 = 39.17381516583167
#
# Cost at iteration 130 = 39.121633331923384
#
# Cost at iteration 131 = 39.07448790860144
#
# Cost at iteration 132 = 39.031880118989385
#
# Cost at iteration 133 = 38.99334950937085
#
# Cost at iteration 134 = 38.95847287534393
#
# Cost at iteration 135 = 38.92686287054059
#
# Cost at iteration 136 = 38.89816636788057
#
# Cost at iteration 137 = 38.871983265546824
#
# Cost at iteration 138 = 38.845817582839196
#
# Cost at iteration 139 = 38.819414948301706
#
# Cost at iteration 140 = 38.794309745327595
#
# Cost at iteration 141 = 38.771027310384824
#
# Cost at iteration 142 = 38.748509285813505
#
# Cost at iteration 143 = 38.72654689441455
#
# Cost at iteration 144 = 38.70579874680406
#
# Cost at iteration 145 = 38.68545951023827
#
# Cost at iteration 146 = 38.66591021528597
#
# Cost at iteration 147 = 38.64744124937399
#
# Cost at iteration 148 = 38.62995447374906
#
# Cost at iteration 149 = 38.61321486848708
#
# Cost at iteration 150 = 38.59700013568359
#
# Cost at iteration 151 = 38.5815383656421
#
# Cost at iteration 152 = 38.56676403895593
#
# Cost at iteration 153 = 38.55238197720838
#
# Cost at iteration 154 = 38.53839385516414
#
# Cost at iteration 155 = 38.52494666247349
#
# Cost at iteration 156 = 38.511995459647565
#
# Cost at iteration 157 = 38.4994989249307
#
# Cost at iteration 158 = 38.48741942967604
#
# Cost at iteration 159 = 38.47572269951198
#
# Cost at iteration 160 = 38.46437750621576
#
# Cost at iteration 161 = 38.45335538692082
#
# Cost at iteration 162 = 38.442630388597344
#
# Cost at iteration 163 = 38.4321553722536
#
# Cost at iteration 164 = 38.42181504987742
#
# Cost at iteration 165 = 38.41144969769218
#
# Cost at iteration 166 = 38.40122908623379
#
# Cost at iteration 167 = 38.391230624908246
#
# Cost at iteration 168 = 38.381438307265014
#
# Cost at iteration 169 = 38.37170141411477
#
# Cost at iteration 170 = 38.36214685534628
#
# Cost at iteration 171 = 38.3527639547414
#
# Cost at iteration 172 = 38.343540895486655
#
# Cost at iteration 173 = 38.33446674923542
#
# Cost at iteration 174 = 38.325531404923275
#
# Cost at iteration 175 = 38.31672550238853
#
# Cost at iteration 176 = 38.30804037178647
#
# Cost at iteration 177 = 38.29946797826224
#
# Cost at iteration 178 = 38.29100087140662
#
# Cost at iteration 179 = 38.28263213906125
#
# Cost at iteration 180 = 38.27435536507889
#
# Cost at iteration 181 = 38.26616459068012
#
# Cost at iteration 182 = 38.258054279080774
#
# Cost at iteration 183 = 38.250019283094495
#
# Cost at iteration 184 = 38.24205481544191
#
# Cost at iteration 185 = 38.23415642152343
#
# Cost at iteration 186 = 38.226319954434835
#
# Cost at iteration 187 = 38.21854155202578
#
# Cost at iteration 188 = 38.21081761582006
#
# Cost at iteration 189 = 38.20314479163317
#
# Cost at iteration 190 = 38.195519951738476
#
# Cost at iteration 191 = 38.18794017844692
#
# Cost at iteration 192 = 38.18040274897783
#
# Cost at iteration 193 = 38.17290512150997
#
# Cost at iteration 194 = 38.16544492231195
#
# Cost at iteration 195 = 38.15801993386055
#
# Cost at iteration 196 = 38.150628083864234
#
# Cost at iteration 197 = 38.14326743511597
#
# Cost at iteration 198 = 38.135936176107094
#
# Cost at iteration 199 = 38.12863261233971
#
# Cost at iteration 200 = 38.12135515828084
#
# Cost at iteration 201 = 38.114102329906636
#
# Cost at iteration 202 = 38.106872737789374
#
# Cost at iteration 203 = 38.09966508068444
#
# Cost at iteration 204 = 38.09247813957781
#
# Cost at iteration 205 = 38.08531077215828
#
# Cost at iteration 206 = 38.07816190768162
#
# Cost at iteration 207 = 38.07103054219664
#
# Cost at iteration 208 = 38.063915734105635
#
# Cost at iteration 209 = 38.05681660003409
#
# Cost at iteration 210 = 38.04973231098653
#
# Cost at iteration 211 = 38.04266208876713
#
# Cost at iteration 212 = 38.03560520264593
#
# Cost at iteration 213 = 38.02856096625237
#
# Cost at iteration 214 = 38.021528734679904
#
# Cost at iteration 215 = 38.01450790178636
#
# Cost at iteration 216 = 38.00749789767615
#
# Cost at iteration 217 = 38.00049818635135
#
# Cost at iteration 218 = 37.993508263519665
#
# Cost at iteration 219 = 37.98652765454851
#
# Cost at iteration 220 = 37.97955591255468
#
# Cost at iteration 221 = 37.97259261662057
#
# Cost at iteration 222 = 37.96563737012786
#
# Cost at iteration 223 = 37.958689799200904
#
# Cost at iteration 224 = 37.95174955125216
#
# Cost at iteration 225 = 37.94481629362283
#
# Cost at iteration 226 = 37.93788971231211
#
# Cost at iteration 227 = 37.930969510789346
#
# Cost at iteration 228 = 37.92405540888323
#
# Cost at iteration 229 = 37.917147141743186
#
# Cost at iteration 230 = 37.910244458867865
#
# Cost at iteration 231 = 37.903347123196546
#
# Cost at iteration 232 = 37.896454910259045
#
# Cost at iteration 233 = 37.88956760738053
#
# Cost at iteration 234 = 37.88268501293741
#
# Cost at iteration 235 = 37.87580693566104
#
# Cost at iteration 236 = 37.868933193986194
#
# Cost at iteration 237 = 37.86206361544121
#
# Cost at iteration 238 = 37.855198036077304
#
# Cost at iteration 239 = 37.84833629993429
#
# Cost at iteration 240 = 37.84147825854055
#
# Cost at iteration 241 = 37.83462377044488
#
# Cost at iteration 242 = 37.827772700778304
#
# Cost at iteration 243 = 37.82092492084374
#
# Cost at iteration 244 = 37.814080307731906
#
# Cost at iteration 245 = 37.80723874396166
#
# Cost at iteration 246 = 37.80040011714324
#
# Cost at iteration 247 = 37.793564319663034
#
# Cost at iteration 248 = 37.786731248388236
#
# Cost at iteration 249 = 37.77990080439044
#
# Cost at iteration 250 = 37.77307289268678
#
# Cost at iteration 251 = 37.76624742199741
#
# Cost at iteration 252 = 37.7594243045186
#
# Cost at iteration 253 = 37.75260345571007
#
# Cost at iteration 254 = 37.74578479409591
#
# Cost at iteration 255 = 37.738968241078105
#
# Cost at iteration 256 = 37.732153720762014
#
# Cost at iteration 257 = 37.72534115979275
#
# Cost at iteration 258 = 37.718530487202074
#
# Cost at iteration 259 = 37.71172163426503
#
# Cost at iteration 260 = 37.704914534365535
#
# Cost at iteration 261 = 37.69810912287065
#
# Cost at iteration 262 = 37.691305337012736
#
# Cost at iteration 263 = 37.68450311577917
#
# Cost at iteration 264 = 37.677702399808965
#
# Cost at iteration 265 = 37.67090313129602
#
# Cost at iteration 266 = 37.664105253898505
#
# Cost at iteration 267 = 37.6573087126539
#
# Cost at iteration 268 = 37.65051345389964
#
# Cost at iteration 269 = 37.64371942519854
#
# Cost at iteration 270 = 37.636926575269115
#
# Cost at iteration 271 = 37.630134853920296
#
# Cost at iteration 272 = 37.62334421199023
#
# Cost at iteration 273 = 37.61655460128906
#
# Cost at iteration 274 = 37.60976597454522
#
# Cost at iteration 275 = 37.602978285355256
#
# Cost at iteration 276 = 37.59619148813673
#
# Cost at iteration 277 = 37.58940553808421
#
# Cost at iteration 278 = 37.58262039112792
#
# Cost at iteration 279 = 37.57583600389518
#
# Cost at iteration 280 = 37.56905233367416
#
# Cost at iteration 281 = 37.56226933837998
#
# Cost at iteration 282 = 37.555486976522985
#
# Cost at iteration 283 = 37.54870520717902
#
# Cost at iteration 284 = 37.54192398996153
#
# Cost at iteration 285 = 37.53514328499555
#
# Cost at iteration 286 = 37.52836305289324
#
# Cost at iteration 287 = 37.521583254731006
#
# Cost at iteration 288 = 37.51480385202812
#
# Cost at iteration 289 = 37.50802480672661
#
# Cost at iteration 290 = 37.5012460811725
#
# Cost at iteration 291 = 37.49446763809821
#
# Cost at iteration 292 = 37.48768944060604
#
# Cost at iteration 293 = 37.4809114521528
#
# Cost at iteration 294 = 37.474133636535335
#
# Cost at iteration 295 = 37.467355957876926
#
# Cost at iteration 296 = 37.4605783806147
#
# Cost at iteration 297 = 37.45380086948771
#
# Cost at iteration 298 = 37.44702338952583
#
# Cost at iteration 299 = 37.44024590603934
#
# Cost at iteration 300 = 37.43346838460917
#
# Cost at iteration 301 = 37.42669079107776
#
# Cost at iteration 302 = 37.419913091540565
#
# Cost at iteration 303 = 37.413135252337966
#
# Cost at iteration 304 = 37.40635724004783
#
# Cost at iteration 305 = 37.39957902147848
#
# Cost at iteration 306 = 37.39280056366211
#
# Cost at iteration 307 = 37.38602183384864
#
# Cost at iteration 308 = 37.379242799499934
#
# Cost at iteration 309 = 37.37246342828446
#
# Cost at iteration 310 = 37.36568368807219
#
# Cost at iteration 311 = 37.358903546929895
#
# Cost at iteration 312 = 37.35212297311671
#
# Cost at iteration 313 = 37.34534193508003
#
# Cost at iteration 314 = 37.3385604014516
#
# Cost at iteration 315 = 37.331778341043936
#
# Cost at iteration 316 = 37.32499572284687
#
# Cost at iteration 317 = 37.318212516024474
#
# Cost at iteration 318 = 37.311428689912006
#
# Cost at iteration 319 = 37.304644214013216
#
# Cost at iteration 320 = 37.29785905799772
#
# Cost at iteration 321 = 37.291073191698594
#
# Cost at iteration 322 = 37.2842865851101
#
# Cost at iteration 323 = 37.27749920838563
#
# Cost at iteration 324 = 37.27071103183567
#
# Cost at iteration 325 = 37.26392202592603
#
# Cost at iteration 326 = 37.257132161276104
#
# Cost at iteration 327 = 37.25034140865726
#
# Cost at iteration 328 = 37.243549738991426
#
# Cost at iteration 329 = 37.23675712334963
#
# Cost at iteration 330 = 37.22996353295079
#
# Cost at iteration 331 = 37.223168939160445
#
# Cost at iteration 332 = 37.21637331348974
#
# Cost at iteration 333 = 37.20957662759436
#
# Cost at iteration 334 = 37.20277885327355
#
# Cost at iteration 335 = 37.19597996246934
#
# Cost at iteration 336 = 37.18917992726561
#
# Cost at iteration 337 = 37.182378719887474
#
# Cost at iteration 338 = 37.17557631270051
#
# Cost at iteration 339 = 37.16877267821016
#
# Cost at iteration 340 = 37.16196778906122
#
# Cost at iteration 341 = 37.15516161803722
#
# Cost at iteration 342 = 37.14835413806001
#
# Cost at iteration 343 = 37.14154532218935
#
# Cost at iteration 344 = 37.1347351436225
#
# Cost at iteration 345 = 37.127923575693885
#
# Cost at iteration 346 = 37.121110591874796
#
# Cost at iteration 347 = 37.114296165773155
#
# Cost at iteration 348 = 37.10748027113321
#
# Cost at iteration 349 = 37.10066288183544
#
# Cost at iteration 350 = 37.093843971896305
#
# Cost at iteration 351 = 37.087023515468154
#
# Cost at iteration 352 = 37.08020148683913
#
# Cost at iteration 353 = 37.07337786043307
#
# Cost at iteration 354 = 37.06655261080945
#
# Cost at iteration 355 = 37.059725712663415
#
# Cost at iteration 356 = 37.052897140825664
#
# Cost at iteration 357 = 37.046066870262614
#
# Cost at iteration 358 = 37.039234876076335
#
# Cost at iteration 359 = 37.03240113350465
#
# Cost at iteration 360 = 37.02556561792125
#
# Cost at iteration 361 = 37.01872830483575
#
# Cost at iteration 362 = 37.01188916989386
#
# Cost at iteration 363 = 37.00504818887747
#
# Cost at iteration 364 = 36.99820533770485
#
# Cost at iteration 365 = 36.991360592430865
#
# Cost at iteration 366 = 36.98451392924706
#
# Cost at iteration 367 = 36.97766532448197
#
# Cost at iteration 368 = 36.970814754601285
#
# Cost at iteration 369 = 36.963962196208136
#
# Cost at iteration 370 = 36.95710762604328
#
# Cost at iteration 371 = 36.95025102098545
#
# Cost at iteration 372 = 36.94339235805156
#
# Cost at iteration 373 = 36.93653161439706
#
# Cost at iteration 374 = 36.9296687673162
#
# Cost at iteration 375 = 36.92280379424238
#
# Cost at iteration 376 = 36.915936672748444
#
# Cost at iteration 377 = 36.90906738054707
#
# Cost at iteration 378 = 36.90219589549108
#
# Cost at iteration 379 = 36.89532219557387
#
# Cost at iteration 380 = 36.88844625892969
#
# Cost at iteration 381 = 36.88156806383412
#
# Cost at iteration 382 = 36.874687588704454
#
# Cost at iteration 383 = 36.86780481210005
#
# Cost at iteration 384 = 36.86091971272284
#
# Cost at iteration 385 = 36.85403226941767
#
# Cost at iteration 386 = 36.847142461172844
#
# Cost at iteration 387 = 36.84025026712045
#
# Cost at iteration 388 = 36.83335566653693
#
# Cost at iteration 389 = 36.826458638843484
#
# Cost at iteration 390 = 36.819559163606556
#
# Cost at iteration 391 = 36.812657220538355
#
# Cost at iteration 392 = 36.80575278949733
#
# Cost at iteration 393 = 36.79884585048865
#
# Cost at iteration 394 = 36.79193638366473
#
# Cost at iteration 395 = 36.78502436932583
#
# Cost at iteration 396 = 36.77810978792044
#
# Cost at iteration 397 = 36.77119262004596
#
# Cost at iteration 398 = 36.764272846449146
#
# Cost at iteration 399 = 36.75735044802671
#
# Cost at iteration 400 = 36.75042540582593
#
# Cost at iteration 401 = 36.74349770104508
#
# Cost at iteration 402 = 36.73656731503416
#
# Cost at iteration 403 = 36.72963422929542
#
# Cost at iteration 404 = 36.722698425483934
#
# Cost at iteration 405 = 36.715759885408225
#
# Cost at iteration 406 = 36.708818591030884
#
# Cost at iteration 407 = 36.70187452446917
#
# Cost at iteration 408 = 36.69492766799563
#
# Cost at iteration 409 = 36.68797800403873
#
# Cost at iteration 410 = 36.68102551518353
#
# Cost at iteration 411 = 36.67407018417226
#
# Cost at iteration 412 = 36.66711199390503
#
# Cost at iteration 413 = 36.66015092744045
#
# Cost at iteration 414 = 36.65318696799634
#
# Cost at iteration 415 = 36.64622009895034
#
# Cost at iteration 416 = 36.639250303840605
#
# Cost at iteration 417 = 36.63227756636655
#
# Cost at iteration 418 = 36.62530187038945
#
# Cost at iteration 419 = 36.61832319993318
#
# Cost at iteration 420 = 36.611341539184934
#
# Cost at iteration 421 = 36.6043568724959
#
# Cost at iteration 422 = 36.59736918438196
#
# Cost at iteration 423 = 36.590378459524466
#
# Cost at iteration 424 = 36.58338468277091
#
# Cost at iteration 425 = 36.57638783913569
#
# Cost at iteration 426 = 36.56938791380082
#
# Cost at iteration 427 = 36.56238489211668
#
# Cost at iteration 428 = 36.55537875960276
#
# Cost at iteration 429 = 36.54836950194844
#
# Cost at iteration 430 = 36.54135710501369
#
# Cost at iteration 431 = 36.534341554829865
#
# Cost at iteration 432 = 36.527322837600465
#
# Cost at iteration 433 = 36.520300939701926
#
# Cost at iteration 434 = 36.51327584768435
#
# Cost at iteration 435 = 36.506247548272306
#
# Cost at iteration 436 = 36.49921602836562
#
# Cost at iteration 437 = 36.49218127504019
#
# Cost at iteration 438 = 36.48514327554868
#
# Cost at iteration 439 = 36.47810201732143
#
# Cost at iteration 440 = 36.471057487967194
#
# Cost at iteration 441 = 36.46400967527394
#
# Cost at iteration 442 = 36.456958567209675
#
# Cost at iteration 443 = 36.449904151923256
#
# Cost at iteration 444 = 36.4428464177452
#
# Cost at iteration 445 = 36.435785353188486
#
# Cost at iteration 446 = 36.42872094694938
#
# Cost at iteration 447 = 36.42165318790828
#
# Cost at iteration 448 = 36.41458206513051
#
# Cost at iteration 449 = 36.40750756786715
#
# Cost at iteration 450 = 36.400429685555906
#
# Cost at iteration 451 = 36.3933484078219
#
# Cost at iteration 452 = 36.38626372447849
#
# Cost at iteration 453 = 36.37917562552818
#
# Cost at iteration 454 = 36.37208410116337
#
# Cost at iteration 455 = 36.36498914176726
#
# Cost at iteration 456 = 36.35789073791468
#
# Cost at iteration 457 = 36.3507888803729
#
# Cost at iteration 458 = 36.34368356010252
#
# Cost at iteration 459 = 36.336574768258274
#
# Cost at iteration 460 = 36.3294624961899
#
# Cost at iteration 461 = 36.322346735443
#
# Cost at iteration 462 = 36.31522747775985
#
# Cost at iteration 463 = 36.30810471508031
#
# Cost at iteration 464 = 36.300978439542575
#
# Cost at iteration 465 = 36.29384864348413
#
# Cost at iteration 466 = 36.28671531944255
#
# Cost at iteration 467 = 36.27957846015633
#
# Cost at iteration 468 = 36.27243805856577
#
# Cost at iteration 469 = 36.265294107813816
#
# Cost at iteration 470 = 36.258146601246864
#
# Cost at iteration 471 = 36.250995532415686
#
# Cost at iteration 472 = 36.24384089507622
#
# Cost at iteration 473 = 36.23668268319041
#
# Cost at iteration 474 = 36.229520890927084
#
# Cost at iteration 475 = 36.22235551266275
#
# Cost at iteration 476 = 36.21518654298252
#
# Cost at iteration 477 = 36.20801397668081
#
# Cost at iteration 478 = 36.20083780876231
#
# Cost at iteration 479 = 36.193658034442734
#
# Cost at iteration 480 = 36.1864746491497
#
# Cost at iteration 481 = 36.17928764852351
#
# Cost at iteration 482 = 36.172097028418
#
# Cost at iteration 483 = 36.16490278490139
#
# Cost at iteration 484 = 36.15770491425702
#
# Cost at iteration 485 = 36.150479638113154
#
# Cost at iteration 486 = 36.14324402353376
#
# Cost at iteration 487 = 36.13600441963996
#
# Cost at iteration 488 = 36.1287608468872
#
# Cost at iteration 489 = 36.12151331659473
#
# Cost at iteration 490 = 36.114261840497086
#
# Cost at iteration 491 = 36.10700642913257
#
# Cost at iteration 492 = 36.099747092246986
#
# Cost at iteration 493 = 36.09248383882138
#
# Cost at iteration 494 = 36.08521667716076
#
# Cost at iteration 495 = 36.077945614964406
#
# Cost at iteration 496 = 36.070670659392945
#
# Cost at iteration 497 = 36.063391817129755
#
# Cost at iteration 498 = 36.056109094437694
#
# Cost at iteration 499 = 36.048822497211596
#
# Cost at iteration 500 = 36.04153203102645
#
# Cost at iteration 501 = 36.0342377011821
#
# Cost at iteration 502 = 36.02693951274433
#
# Cost at iteration 503 = 36.01963747058279
#
# Cost at iteration 504 = 36.0123315794061
#
# Cost at iteration 505 = 36.0050176227919
#
# Cost at iteration 506 = 35.99769539683716
#
# Cost at iteration 507 = 35.990369186298786
#
# Cost at iteration 508 = 35.98303903389419
#
# Cost at iteration 509 = 35.97570494577665
#
# Cost at iteration 510 = 35.96836693477013
#
# Cost at iteration 511 = 35.9610250116073
#
# Cost at iteration 512 = 35.95367918681743
#
# Cost at iteration 513 = 35.94632947041194
#
# Cost at iteration 514 = 35.93897587202057
#
# Cost at iteration 515 = 35.93161840092783
#
# Cost at iteration 516 = 35.9242570661253
#
# Cost at iteration 517 = 35.916891876355606
#
# Cost at iteration 518 = 35.90952284015388
#
# Cost at iteration 519 = 35.90214996588562
#
# Cost at iteration 520 = 35.89477326178156
#
# Cost at iteration 521 = 35.88739273596974
#
# Cost at iteration 522 = 35.880008396505026
#
# Cost at iteration 523 = 35.87262025139619
#
# Cost at iteration 524 = 35.865228308630854
#
# Cost at iteration 525 = 35.857832576198426
#
# Cost at iteration 526 = 35.85043306211116
#
# Cost at iteration 527 = 35.84302977442351
#
# Cost at iteration 528 = 35.83562272125003
#
# Cost at iteration 529 = 35.828211910781626
#
# Cost at iteration 530 = 35.820797351300676
#
# Cost at iteration 531 = 35.81337905119484
#
# Cost at iteration 532 = 35.805957018969806
#
# Cost at iteration 533 = 35.79853126326091
#
# Cost at iteration 534 = 35.79110179284389
#
# Cost at iteration 535 = 35.78366861664477
#
# Cost at iteration 536 = 35.77623174374888
#
# Cost at iteration 537 = 35.76879118340921
#
# Cost at iteration 538 = 35.76134694505401
#
# Cost at iteration 539 = 35.75389903829383
#
# Cost at iteration 540 = 35.74644747292793
#
# Cost at iteration 541 = 35.738992258950226
#
# Cost at iteration 542 = 35.731533406554675
#
# Cost at iteration 543 = 35.724070926140236
#
# Cost at iteration 544 = 35.71660482831544
#
# Cost at iteration 545 = 35.70913512390257
#
# Cost at iteration 546 = 35.701661823941464
#
# Cost at iteration 547 = 35.694184939692995
#
# Cost at iteration 548 = 35.68670448264228
#
# Cost at iteration 549 = 35.67922046450159
#
# Cost at iteration 550 = 35.67173289721304
#
# Cost at iteration 551 = 35.664241792950946
#
# Cost at iteration 552 = 35.65674716412408
#
# Cost at iteration 553 = 35.64924902337768
#
# Cost at iteration 554 = 35.64174738359518
#
# Cost at iteration 555 = 35.63424225789997
#
# Cost at iteration 556 = 35.62673365965677
#
# Cost at iteration 557 = 35.61922160247302
#
# Cost at iteration 558 = 35.61170610020002
#
# Cost at iteration 559 = 35.60418716693401
#
# Cost at iteration 560 = 35.596664817017135
#
# Cost at iteration 561 = 35.5891390650382
#
# Cost at iteration 562 = 35.58160992583341
#
# Cost at iteration 563 = 35.57407741448701
#
# Cost at iteration 564 = 35.566541546331784
#
# Cost at iteration 565 = 35.55900233694948
#
# Cost at iteration 566 = 35.55145980217117
#
# Cost at iteration 567 = 35.54391395807754
#
# Cost at iteration 568 = 35.53636482099903
#
# Cost at iteration 569 = 35.52881240751605
#
# Cost at iteration 570 = 35.52125673445892
#
# Cost at iteration 571 = 35.51369781890801
#
# Cost at iteration 572 = 35.50613567819355
#
# Cost at iteration 573 = 35.49857032989557
#
# Cost at iteration 574 = 35.49100179184374
#
# Cost at iteration 575 = 35.48343008211708
#
# Cost at iteration 576 = 35.475855219043716
#
# Cost at iteration 577 = 35.46827722120054
#
# Cost at iteration 578 = 35.460696107412836
#
# Cost at iteration 579 = 35.453111896753846
#
# Cost at iteration 580 = 35.44552460854428
#
# Cost at iteration 581 = 35.43793426235186
#
# Cost at iteration 582 = 35.43034087799067
#
# Cost at iteration 583 = 35.422744475520645
#
# Cost at iteration 584 = 35.41514507524685
#
# Cost at iteration 585 = 35.40754269771886
#
# Cost at iteration 586 = 35.39993736373
#
# Cost at iteration 587 = 35.3923290943166
#
# Cost at iteration 588 = 35.38471791075717
#
# Cost at iteration 589 = 35.377103834571614
#
# Cost at iteration 590 = 35.36948688752029
#
# Cost at iteration 591 = 35.36186709160313
#
# Cost at iteration 592 = 35.3542444690587
#
# Cost at iteration 593 = 35.346619042363194
#
# Cost at iteration 594 = 35.33899083422941
#
# Cost at iteration 595 = 35.33135986760571
#
# Cost at iteration 596 = 35.3237261656749
#
# Cost at iteration 597 = 35.31608975185311
#
# Cost at iteration 598 = 35.308450649788654
#
# Cost at iteration 599 = 35.30080888336077
#
# Cost at iteration 600 = 35.29316447667845
#
# Cost at iteration 601 = 35.28551745407911
#
# Cost at iteration 602 = 35.27786784012735
#
# Cost at iteration 603 = 35.27021565961351
#
# Cost at iteration 604 = 35.262560937552415
#
# Cost at iteration 605 = 35.25490369918188
#
# Cost at iteration 606 = 35.24724396996127
#
# Cost at iteration 607 = 35.23958177557007
#
# Cost at iteration 608 = 35.23191714190632
#
# Cost at iteration 609 = 35.22425009508507
#
# Cost at iteration 610 = 35.216580661436836
#
# Cost at iteration 611 = 35.208908867505926
#
# Cost at iteration 612 = 35.201234740048804
#
# Cost at iteration 613 = 35.19355830603245
#
# Cost at iteration 614 = 35.185879592632546
#
# Cost at iteration 615 = 35.1781986272318
#
# Cost at iteration 616 = 35.17051543741811
#
# Cost at iteration 617 = 35.16283005098274
#
# Cost at iteration 618 = 35.15514249591849
#
# Cost at iteration 619 = 35.147452800417774
#
# Cost at iteration 620 = 35.13976099287068
#
# Cost at iteration 621 = 35.132067101863036
#
# Cost at iteration 622 = 35.124371156174426
#
# Cost at iteration 623 = 35.11667318477608
#
# Cost at iteration 624 = 35.108973216828915
#
# Cost at iteration 625 = 35.10127128168134
#
# Cost at iteration 626 = 35.0935674088672
#
# Cost at iteration 627 = 35.08586162810355
#
# Cost at iteration 628 = 35.0781539692885
#
# Cost at iteration 629 = 35.07044446249895
#
# Cost at iteration 630 = 35.06273313798833
#
# Cost at iteration 631 = 35.055020026184316
#
# Cost at iteration 632 = 35.04730515768648
#
# Cost at iteration 633 = 35.03958856326393
#
# Cost at iteration 634 = 35.03187027385292
#
# Cost at iteration 635 = 35.02415032055437
#
# Cost at iteration 636 = 35.01642873463149
#
# Cost at iteration 637 = 35.0087055475072
#
# Cost at iteration 638 = 35.00098079076164
#
# Cost at iteration 639 = 34.9932544961296
#
# Cost at iteration 640 = 34.98552669549797
#
# Cost at iteration 641 = 34.977797420903
#
# Cost at iteration 642 = 34.970066704527824
#
# Cost at iteration 643 = 34.96233457869958
#
# Cost at iteration 644 = 34.95460107588684
#
# Cost at iteration 645 = 34.946866228696784
#
# Cost at iteration 646 = 34.93913006987247
#
# Cost at iteration 647 = 34.93139263228998
#
# Cost at iteration 648 = 34.92365394895561
#
# Cost at iteration 649 = 34.91591405300301
#
# Cost at iteration 650 = 34.90817297769027
#
# Cost at iteration 651 = 34.900430756397
#
# Cost at iteration 652 = 34.8926874226214
#
# Cost at iteration 653 = 34.884943009977206
#
# Cost at iteration 654 = 34.87719755219077
#
# Cost at iteration 655 = 34.869451083098
#
# Cost at iteration 656 = 34.86170363664123
#
# Cost at iteration 657 = 34.853955246866214
#
# Cost at iteration 658 = 34.84619934585917
#
# Cost at iteration 659 = 34.83843807187854
#
# Cost at iteration 660 = 34.83067569740686
#
# Cost at iteration 661 = 34.822912308849794
#
# Cost at iteration 662 = 34.815147946580716
#
# Cost at iteration 663 = 34.80738266954484
#
# Cost at iteration 664 = 34.799616525244545
#
# Cost at iteration 665 = 34.79184956418918
#
# Cost at iteration 666 = 34.78408183330069
#
# Cost at iteration 667 = 34.77631337928729
#
# Cost at iteration 668 = 34.76854424723522
#
# Cost at iteration 669 = 34.760774481472346
#
# Cost at iteration 670 = 34.75300412531704
#
# Cost at iteration 671 = 34.745233221349345
#
# Cost at iteration 672 = 34.73746181141196
#
# Cost at iteration 673 = 34.729689936729066
#
# Cost at iteration 674 = 34.72191763795429
#
# Cost at iteration 675 = 34.7141449552421
#
# Cost at iteration 676 = 34.70637192829708
#
# Cost at iteration 677 = 34.698598596424844
#
# Cost at iteration 678 = 34.69082499857369
#
# Cost at iteration 679 = 34.68305117337331
#
# Cost at iteration 680 = 34.67527715916814
#
# Cost at iteration 681 = 34.6675029940473
#
# Cost at iteration 682 = 34.65972871587078
#
# Cost at iteration 683 = 34.651954362292535
#
# Cost at iteration 684 = 34.64417997078079
#
# Cost at iteration 685 = 34.63640557863572
#
# Cost at iteration 686 = 34.62863122300494
#
# Cost at iteration 687 = 34.62085694089691
#
# Cost at iteration 688 = 34.61308276919253
#
# Cost at iteration 689 = 34.60530874465511
#
# Cost at iteration 690 = 34.597534903938836
#
# Cost at iteration 691 = 34.58976128359597
#
# Cost at iteration 692 = 34.581987920082845
#
# Cost at iteration 693 = 34.57421484976483
#
# Cost at iteration 694 = 34.56644210892034
#
# Cost at iteration 695 = 34.55866973374401
#
# Cost at iteration 696 = 34.55089776034911
#
# Cost at iteration 697 = 34.54312622476931
#
# Cost at iteration 698 = 34.535355162959796
#
# Cost at iteration 699 = 34.52758461079794
#
# Cost at iteration 700 = 34.519814604083344
#
# Cost at iteration 701 = 34.512045178537655
#
# Cost at iteration 702 = 34.50427636980378
#
# Cost at iteration 703 = 34.49650821344494
#
# Cost at iteration 704 = 34.4887407449433
#
# Cost at iteration 705 = 34.48097399969844
#
# Cost at iteration 706 = 34.473208013025456
#
# Cost at iteration 707 = 34.46544282015296
#
# Cost at iteration 708 = 34.45767845622083
#
# Cost at iteration 709 = 34.449914956277816
#
# Cost at iteration 710 = 34.442152355279006
#
# Cost at iteration 711 = 34.434390688083084
#
# Cost at iteration 712 = 34.42662998944962
#
# Cost at iteration 713 = 34.41887029403611
#
# Cost at iteration 714 = 34.41111163639501
#
# Cost at iteration 715 = 34.40335405097068
#
# Cost at iteration 716 = 34.395597572096214
#
# Cost at iteration 717 = 34.3878422339903
#
# Cost at iteration 718 = 34.380088070753956
#
# Cost at iteration 719 = 34.37233511636722
#
# Cost at iteration 720 = 34.364583404685874
#
# Cost at iteration 721 = 34.35683296943806
#
# Cost at iteration 722 = 34.349083844220914
#
# Cost at iteration 723 = 34.341336062497184
#
# Cost at iteration 724 = 34.33358965759179
#
# Cost at iteration 725 = 34.3258446626884
#
# Cost at iteration 726 = 34.31810111082606
#
# Cost at iteration 727 = 34.31035903489568
#
# Cost at iteration 728 = 34.302618467636634
#
# Cost at iteration 729 = 34.294879441633334
#
# Cost at iteration 730 = 34.28714198931178
#
# Cost at iteration 731 = 34.27940614293613
#
# Cost at iteration 732 = 34.27167193460535
#
# Cost at iteration 733 = 34.26393939624969
#
# Cost at iteration 734 = 34.2562085596274
#
# Cost at iteration 735 = 34.248479456321306
#
# Cost at iteration 736 = 34.24075211773544
#
# Cost at iteration 737 = 34.23302657509173
#
# Cost at iteration 738 = 34.22530285942661
#
# Cost at iteration 739 = 34.21758100158782
#
# Cost at iteration 740 = 34.20986103223099
#
# Cost at iteration 741 = 34.20214298181648
#
# Cost at iteration 742 = 34.194426880606116
#
# Cost at iteration 743 = 34.18671275865994
#
# Cost at iteration 744 = 34.17900064583305
#
# Cost at iteration 745 = 34.17129057177244
#
# Cost at iteration 746 = 34.163582565913885
#
# Cost at iteration 747 = 34.15587665747877
#
# Cost at iteration 748 = 34.14817287547106
#
# Cost at iteration 749 = 34.140471248674295
#
# Cost at iteration 750 = 34.132771805648446
#
# Cost at iteration 751 = 34.12507457472707
#
# Cost at iteration 752 = 34.11737958401427
#
# Cost at iteration 753 = 34.10968686138181
#
# Cost at iteration 754 = 34.10199643446621
#
# Cost at iteration 755 = 34.094308330665896
#
# Cost at iteration 756 = 34.08662257713841
#
# Cost at iteration 757 = 34.07893920079758
#
# Cost at iteration 758 = 34.07125822831081
#
# Cost at iteration 759 = 34.06357968609637
#
# Cost at iteration 760 = 34.05590360032069
#
# Cost at iteration 761 = 34.048229996895756
#
# Cost at iteration 762 = 34.040558901476494
#
# Cost at iteration 763 = 34.032890339458234
#
# Cost at iteration 764 = 34.025224335974144
#
# Cost at iteration 765 = 34.017560915892794
#
# Cost at iteration 766 = 34.009900103815724
#
# Cost at iteration 767 = 34.00224192407495
#
# Cost at iteration 768 = 33.994586400730746
#
# Cost at iteration 769 = 33.986933557569216
#
# Cost at iteration 770 = 33.97928341810004
#
# Cost at iteration 771 = 33.97163600555427
#
# Cost at iteration 772 = 33.96399134288211
#
# Cost at iteration 773 = 33.95634945275075
#
# Cost at iteration 774 = 33.94871035754233
#
# Cost at iteration 775 = 33.941074079351765
#
# Cost at iteration 776 = 33.93344063998481
#
# Cost at iteration 777 = 33.92581006095607
#
# Cost at iteration 778 = 33.91818236348701
#
# Cost at iteration 779 = 33.910557568504146
#
# Cost at iteration 780 = 33.902935696637144
#
# Cost at iteration 781 = 33.89531676821705
#
# Cost at iteration 782 = 33.88770080327448
#
# Cost at iteration 783 = 33.880087821538
#
# Cost at iteration 784 = 33.872477842432396
#
# Cost at iteration 785 = 33.86487088507707
#
# Cost at iteration 786 = 33.85726696828448
#
# Cost at iteration 787 = 33.84965795808726
#
# Cost at iteration 788 = 33.84201840158003
#
# Cost at iteration 789 = 33.834381086482466
#
# Cost at iteration 790 = 33.82674667424907
#
# Cost at iteration 791 = 33.819114759039785
#
# Cost at iteration 792 = 33.81148581741788
#
# Cost at iteration 793 = 33.80385956581591
#
# Cost at iteration 794 = 33.79623635351804
#
# Cost at iteration 795 = 33.788615979562906
#
# Cost at iteration 796 = 33.78099870438825
#
# Cost at iteration 797 = 33.77338438361129
#
# Cost at iteration 798 = 33.765773214805556
#
# Cost at iteration 799 = 33.758165092864694
#
# Cost at iteration 800 = 33.75056017028994
#
# Cost at iteration 801 = 33.74295836959695
#
# Cost at iteration 802 = 33.7353598105492
#
# Cost at iteration 803 = 33.72776443532859
#
# Cost at iteration 804 = 33.72017233961367
#
# Cost at iteration 805 = 33.71258347974725
#
# Cost at iteration 806 = 33.70499793346263
#
# Cost at iteration 807 = 33.697415667400925
#
# Cost at iteration 808 = 33.68983674575462
#
# Cost at iteration 809 = 33.68226114271466
#
# Cost at iteration 810 = 33.67468891212634
#
# Cost at iteration 811 = 33.6671200337465
#
# Cost at iteration 812 = 33.65955455341338
#
# Cost at iteration 813 = 33.65199245499651
#
# Cost at iteration 814 = 33.644433778059856
#
# Cost at iteration 815 = 33.636878509505266
#
# Cost at iteration 816 = 33.62932668391926
#
# Cost at iteration 817 = 33.621778290420266
#
# Cost at iteration 818 = 33.61423335959893
#
# Cost at iteration 819 = 33.606691882164235
#
# Cost at iteration 820 = 33.599153885463025
#
# Cost at iteration 821 = 33.591619361306144
#
# Cost at iteration 822 = 33.58408833438069
#
# Cost at iteration 823 = 33.576560797210675
#
# Cost at iteration 824 = 33.5690367722843
#
# Cost at iteration 825 = 33.561516252522935
#
# Cost at iteration 826 = 33.55397463463188
#
# Cost at iteration 827 = 33.54640157677912
#
# Cost at iteration 828 = 33.538831387065244
#
# Cost at iteration 829 = 33.53126433043456
#
# Cost at iteration 830 = 33.52370030257029
#
# Cost at iteration 831 = 33.516139541145456
#
# Cost at iteration 832 = 33.508581927233315
#
# Cost at iteration 833 = 33.501027679659785
#
# Cost at iteration 834 = 33.49347666702122
#
# Cost at iteration 835 = 33.485929096094296
#
# Cost at iteration 836 = 33.478384823924415
#
# Cost at iteration 837 = 33.47084405092333
#
# Cost at iteration 838 = 33.463306622518566
#
# Cost at iteration 839 = 33.45577273773846
#
# Cost at iteration 840 = 33.448242229457314
#
# Cost at iteration 841 = 33.44071529994235
#
# Cost at iteration 842 = 33.43319176775801
#
# Cost at iteration 843 = 33.42567184297904
#
# Cost at iteration 844 = 33.41815532725771
#
# Cost at iteration 845 = 33.41064244328528
#
# Cost at iteration 846 = 33.40313297225653
#
# Cost at iteration 847 = 33.395627154837065
#
# Cost at iteration 848 = 33.388124747097656
#
# Cost at iteration 849 = 33.38062601393606
#
# Cost at iteration 850 = 33.37313068023526
#
# Cost at iteration 851 = 33.36563904271069
#
# Cost at iteration 852 = 33.35815078719469
#
# Cost at iteration 853 = 33.35066625168157
#
# Cost at iteration 854 = 33.34318507272046
#
# Cost at iteration 855 = 33.335707641648995
#
# Cost at iteration 856 = 33.328233532327154
#
# Cost at iteration 857 = 33.32076320509368
#
# Cost at iteration 858 = 33.313296153407926
#
# Cost at iteration 859 = 33.30583292723319
#
# Cost at iteration 860 = 33.298372916009605
#
# Cost at iteration 861 = 33.29091678684351
#
# Cost at iteration 862 = 33.28346379334842
#
# Cost at iteration 863 = 33.27601475693248
#
# Cost at iteration 864 = 33.26856875211042
#
# Cost at iteration 865 = 33.26112680534007
#
# Cost at iteration 866 = 33.253687752554896
#
# Cost at iteration 867 = 33.24625289533778
#
# Cost at iteration 868 = 33.23882074841104
#
# Cost at iteration 869 = 33.231392986308265
#
# Cost at iteration 870 = 33.223967686525384
#
# Cost at iteration 871 = 33.21654703460889
#
# Cost at iteration 872 = 33.20912850617177
#
# Cost at iteration 873 = 33.20171499476722
#
# Cost at iteration 874 = 33.1943031378681
#
# Cost at iteration 875 = 33.186896821233056
#
# Cost at iteration 876 = 33.17949150143701
#
# Cost at iteration 877 = 33.17209247104174
#
# Cost at iteration 878 = 33.16469350287479
#
# Cost at iteration 879 = 33.1573019079634
#
# Cost at iteration 880 = 33.14990902930538
#
# Cost at iteration 881 = 33.142525109082975
#
# Cost at iteration 882 = 33.135137940816904
#
# Cost at iteration 883 = 33.12776207538613
#
# Cost at iteration 884 = 33.12038005716235
#
# Cost at iteration 885 = 33.11301284900764
#
# Cost at iteration 886 = 33.10562628134132
#
# Cost at iteration 887 = 33.09820955630769
#
# Cost at iteration 888 = 33.09077781244693
#
# Cost at iteration 889 = 33.08336435969362
#
# Cost at iteration 890 = 33.075926323740205
#
# Cost at iteration 891 = 33.06851965259383
#
# Cost at iteration 892 = 33.0610808922835
#
# Cost at iteration 893 = 33.053688829821304
#
# Cost at iteration 894 = 33.0462455171713
#
# Cost at iteration 895 = 33.038873315439474
#
# Cost at iteration 896 = 33.0314189816678
#
# Cost at iteration 897 = 33.02407521345671
#
# Cost at iteration 898 = 33.0165989821912
#
# Cost at iteration 899 = 33.00929796173707
#
# Cost at iteration 900 = 33.001781461806424
#
# Cost at iteration 901 = 32.994547507004924
#
# Cost at iteration 902 = 32.986959459944046
#
# Cost at iteration 903 = 32.97983453765683
#
# Cost at iteration 904 = 32.97212124305252
#
# Cost at iteration 905 = 32.965178967862364
#
# Cost at iteration 906 = 32.95724761239634
#
# Cost at iteration 907 = 32.95061954773426
#
# Cost at iteration 908 = 32.94230930739418
#
# Cost at iteration 909 = 32.9362361353624
#
# Cost at iteration 910 = 32.927269995602636
#
# Cost at iteration 911 = 32.922206062930165
#
# Cost at iteration 912 = 32.91204013852649
#
# Cost at iteration 913 = 32.908957674022666
#
# Cost at iteration 914 = 32.896742939369865
#
# Cost at iteration 915 = 32.897636707446836
#
# Cost at iteration 916 = 32.88226704210434
#
# Cost at iteration 917 = 32.89123268040449
#
# Cost at iteration 918 = 32.87230913627484
#
# Cost at iteration 919 = 32.89826193372708
#
# Cost at iteration 920 = 32.87955419892435
#
# Cost at iteration 921 = 32.952187895063915
#
# Cost at iteration 922 = 32.95686337051872
#
# Cost at iteration 923 = 33.17543676984431
#
# Cost at iteration 924 = 33.32700594493658
#
# Cost at iteration 925 = 34.00905709313031
#
# Cost at iteration 926 = 34.84378560305282
#
# Cost at iteration 927 = 37.048926347267084
#
# Cost at iteration 928 = 40.66271966495225
#
# Cost at iteration 929 = 47.1315329392595
#
# Cost at iteration 930 = 59.403197612897266
#
# Cost at iteration 931 = 69.80973715312486
#
# Cost at iteration 932 = 94.17670573552012
#
# Cost at iteration 933 = 78.0580284860264
#
# Cost at iteration 934 = 87.31382422942198
#
# Cost at iteration 935 = 52.70681132750742
#
# Cost at iteration 936 = 49.313488873069026
#
# Cost at iteration 937 = 39.489892661982445
#
# Cost at iteration 938 = 37.52293164102698
#
# Cost at iteration 939 = 35.3181150284106
#
# Cost at iteration 940 = 34.605275957786404
#
# Cost at iteration 941 = 34.01724649258089
#
# Cost at iteration 942 = 33.763176675540784
#
# Cost at iteration 943 = 33.578185630619025
#
# Cost at iteration 944 = 33.47997657034973
#
# Cost at iteration 945 = 33.41117100353677
#
# Cost at iteration 946 = 33.36678160848978
#
# Cost at iteration 947 = 33.3366548219615
#
# Cost at iteration 948 = 33.311313609802056
#
# Cost at iteration 949 = 33.29624658045143
#
# Cost at iteration 950 = 33.2777808453516
#
# Cost at iteration 951 = 33.268311448974465
#
# Cost at iteration 952 = 33.25335475493831
#
# Cost at iteration 953 = 33.245189442195375
#
# Cost at iteration 954 = 33.233008274243396
#
# Cost at iteration 955 = 33.2252614504913
#
# Cost at iteration 956 = 33.21462077098619
#
# Cost at iteration 957 = 33.20697508470363
#
# Cost at iteration 958 = 33.19724058391141
#
# Cost at iteration 959 = 33.18958779606954
#
# Cost at iteration 960 = 33.180413449780374
#
# Cost at iteration 961 = 33.1727231707287
#
# Cost at iteration 962 = 33.16391035338602
#
# Cost at iteration 963 = 33.15618032201089
#
# Cost at iteration 964 = 33.1476099825293
#
# Cost at iteration 965 = 33.13984697502975
#
# Cost at iteration 966 = 33.13144507112897
#
# Cost at iteration 967 = 33.123657705554756
#
# Cost at iteration 968 = 33.11537669979342
#
# Cost at iteration 969 = 33.10757292870378
#
# Cost at iteration 970 = 33.09938145057325
#
# Cost at iteration 971 = 33.09156788046809
#
# Cost at iteration 972 = 33.08344472948582
#
# Cost at iteration 973 = 33.07562661377582
#
# Cost at iteration 974 = 33.067557162087894
#
# Cost at iteration 975 = 33.05973860583235
#
# Cost at iteration 976 = 33.05171257411682
#
# Cost at iteration 977 = 33.04389677206473
#
# Cost at iteration 978 = 33.03590681470355
#
# Cost at iteration 979 = 33.028096265847836
#
# Cost at iteration 980 = 33.0201370565973
#
# Cost at iteration 981 = 33.01233373315856
#
# Cost at iteration 982 = 33.00440134725381
#
# Cost at iteration 983 = 32.996606826218944
#
# Cost at iteration 984 = 32.98869833133924
#
# Cost at iteration 985 = 32.98091390888423
#
# Cost at iteration 986 = 32.97302707592079
#
# Cost at iteration 987 = 32.96525379899127
#
# Cost at iteration 988 = 32.957386877982756
#
# Cost at iteration 989 = 32.94962564525222
#
# Cost at iteration 990 = 32.94177725114976
#
# Cost at iteration 991 = 32.934028843863686
#
# Cost at iteration 992 = 32.92619783871084
#
# Cost at iteration 993 = 32.91846295738094
#
# Cost at iteration 994 = 32.91064837046928
#
# Cost at iteration 995 = 32.90292766627528
#
# Cost at iteration 996 = 32.8951286318687
#
# Cost at iteration 997 = 32.88742275290086
#
# Cost at iteration 998 = 32.879638518623494
#
# Cost at iteration 999 = 32.87194812145965
#
# Cost at iteration 1000 = 32.86417782569411
#
# Root Mean Squared Error on Training Data = 8.10635597146381
# Root Mean Squared Error on Test Data = 9.008550608751412
